# %%
import pandas as pd
import numpy as np
import statistics as st

# %%
df = pd.read_csv('IMDB-Movie-Data.csv')

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
#mean calculation
df.mean()
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_16560\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Rank                     500.500000
# Year                    2012.783000
# Runtime (Minutes)        113.172000
# Rating                     6.723200
# Votes                 169808.255000
# Revenue (Millions)        82.956376
# Metascore                 58.985043
# dtype: float64

# %%
#calculate the mean of the variables 'Year' and 'Votes'
print(df.loc[:,'Year'].mean())
print(df.loc[:,'Votes'].mean())
# Out:
# 2012.783
# 169808.255

# %%
#calculates the mean of the first five rows
df.mean(axis = 1)[0:5]
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_16560\1363340859.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis = 1)[0:5]
# 0    108518.175714
# 1     69736.637143
# 2     22849.917143
# 3      9001.360000
# 4     56606.031429
# dtype: float64

# %%
#median
df.median()
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_16560\1739800283.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Rank                     500.500
# Year                    2014.000
# Runtime (Minutes)        111.000
# Rating                     6.800
# Votes                 110799.000
# Revenue (Millions)        47.985
# Metascore                 59.500
# dtype: float64

# %%
#to calculate a median of a particular column
print(df.loc[:,'Year'].median())
print(df.loc[:,'Votes'].median())
# Out:
# 2014.0
# 110799.0

# %%
df.median(axis = 1)[0:5]
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_16560\1941941222.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median(axis = 1)[0:5]
# 0    121.0
# 1    124.0
# 2    117.0
# 3    108.0
# 4    123.0
# dtype: float64

# %%
df.mode()
# Out:
#      Rank     Title                    Genre  \
# 0       1  The Host  Action,Adventure,Sci-Fi
# 1       2       NaN                      NaN
# 2       3       NaN                      NaN
# 3       4       NaN                      NaN
# 4       5       NaN                      NaN
# ..    ...       ...                      ...
# 995   996       NaN                      NaN
# 996   997       NaN                      NaN
# 997   998       NaN                      NaN
# 998   999       NaN                      NaN
# 999  1000       NaN                      NaN
#
#                                            Description      Director  \
# 0    "21" is the fact-based story about six MIT stu...  Ridley Scott
# 1    "Mr. Church" tells the story of a unique frien...           NaN
# 2    "The Thinning" takes place in a post-apocalypt...           NaN
# 3    #1 NASCAR driver Ricky Bobby stays atop the he...           NaN
# 4    12-year-old orphan Peter is spirited away to t...           NaN
# ...

# %%
#standard derivation
df.std()
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_16560\454836062.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# Rank                     288.819436
# Year                       3.205962
# Runtime (Minutes)         18.810908
# Rating                     0.945429
# Votes                 188762.647518
# Revenue (Millions)       103.253540
# Metascore                 17.194757
# dtype: float64

# %%
print(df.loc[:,'Year'].std())
print(df.loc[:,'Votes'].std())
# Out:
# 3.205961507752267
# 188762.6475182208

# %%
df.std(axis = 1)[0:5]
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_16560\3585816795.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std(axis = 1)[0:5]
# 0    285987.140710
# 1    183476.958712
# 2     59426.314556
# 3     22740.119443
# 4    148658.129981
# dtype: float64

# %%
df.groupby(['Year']).mean()
# Out:
#             Rank  Runtime (Minutes)    Rating          Votes  \
# Year
# 2006  588.500000         120.840909  7.125000  269289.954545
# 2007  576.584906         121.622642  7.133962  244331.037736
# 2008  625.634615         110.826923  6.784615  275505.384615
# 2009  586.823529         116.117647  6.960784  255780.647059
# 2010  587.316667         111.133333  6.826667  252782.316667
# 2011  589.571429         114.603175  6.838095  240790.301587
# 2012  532.875000         119.109375  6.925000  285226.093750
# 2013  556.230769         116.065934  6.812088  219049.648352
# 2014  512.979592         114.489796  6.837755  203930.224490
# 2015  491.393701         114.496063  6.602362  115726.220472
# 2016  376.444444         107.373737  6.436700   48591.754209
#
#       Revenue (Millions)  Metascore
# Year
# 2006           86.296667  64.414634
# 2007           87.882245  64.500000
# 2008           99.082745  57.408163
# 2009          112.601277  57.122449
# ...

# %%
df.dropna()
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
dtf = pd.read_csv('Iris.csv')

# %%
dtf
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print('Iris-setosa')
setosa = dtf['Species'] == 'Iris-setosa'
print(dtf[setosa].describe())
# Out:
# Iris-setosa
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000

# %%
print('\nIris-versicolor')
setosa = dtf['Species'] == 'Iris-versicolor'
print(dtf[setosa].describe())
# Out:
# Iris-versicolor
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# std     14.57738       0.516171      0.313798       0.469911      0.197753
# min     51.00000       4.900000      2.000000       3.000000      1.000000
# 25%     63.25000       5.600000      2.525000       4.000000      1.200000
# 50%     75.50000       5.900000      2.800000       4.350000      1.300000
# 75%     87.75000       6.300000      3.000000       4.600000      1.500000
# max    100.00000       7.000000      3.400000       5.100000      1.800000

# %%
print('\nIris-virginica')
setosa = dtf['Species'] == 'Iris-virginica'
print(dtf[setosa].describe())
# Out:
# Iris-virginica
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000       50.00000     50.000000      50.000000      50.00000
# mean   125.50000        6.58800      2.974000       5.552000       2.02600
# std     14.57738        0.63588      0.322497       0.551895       0.27465
# min    101.00000        4.90000      2.200000       4.500000       1.40000
# 25%    113.25000        6.22500      2.800000       5.100000       1.80000
# 50%    125.50000        6.50000      3.000000       5.550000       2.00000
# 75%    137.75000        6.90000      3.175000       5.875000       2.30000
# max    150.00000        7.90000      3.800000       6.900000       2.50000
